# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart_patients.csv")

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality  ',
#        'Marital status                       ',
#        'Life.Style                                                                              ',
#        'Sleep', 'Category', 'Depression', 'Hyperlipi', 'Smoking',
#        'Family.History', 'F.History', 'Diabetes', 'HTN', 'Allergies', 'BP',
#        'Thrombolysis', 'BGR', 'B.Urea', 'S.Cr', 'S.Sodium', 'S.Potassium',
#        'S.Chloride', 'C.P.K', 'CK.MB', 'ESR', 'WBC', 'RBC', 'Hemoglobin',
#        'P.C.V', 'M.C.V', 'M.C.H', 'M.C.H.C', 'PLATELET_COUNT', 'NEUTROPHIL',
#        'LYMPHO', 'MONOCYTE', 'EOSINO', 'Others ', 'CO', 'Diagnosis',
#        'Hypersensitivity', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num', 'SK',
#        'SK.React', 'Reaction', 'Mortality', 'Follow.Up'],
#       dtype='object')

# %%
df.head(3)  #show the  desired rows from top
# Out:
#    Age Age.Group  Gender Locality   Marital status                         \
# 0   45     41-50  Female      RURAL                               MARRIED
# 1   51     51-60  Female      URBAN                               MARRIED
# 2   55     51-60  Female      RURAL                               MARRIED
#
#   Life.Style                                                                                \
# 0                                                 NO
# 1                                                 NO
# 2                                                YES
#
#   Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num SK  \
# 0    NO     FREE        YES       YES  ...     3.0     2   0     7   2  1
# 1    NO     FREE        YES       YES  ...     1.2     2   0     7   2  1
# 2   YES     FREE        YES       YES  ...     3.4     2   0     3   2  1
#
#    SK.React  Reaction  Mortality  Follow.Up
# 0        NO         0          0       60.0
# ...

# %%
df.shape #show the data shape (rows and columns)
# Out:
# (368, 60)

# %%
df.tail(2) # display the end rows
# Out:
#      Age Age.Group Gender Locality   Marital status                         \
# 366   58     51-60   Male      URBAN                               MARRIED
# 367   50     41-50   Male      RURAL                               MARRIED
#
#     Life.Style                                                                                \
# 366                                                 NO
# 367                                                YES
#
#     Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num SK  \
# 366    NO     FREE        YES       YES  ...     2.6     2   0     7   4  1
# 367    NO     FREE        YES       YES  ...     0.6     2   1     7   1  1
#
#            SK.React  Reaction  Mortality  Follow.Up
# 366  COUGH.BLEEDING         1          0       32.0
# 367       BODY.PAIN         1          0       15.0
#
# [2 rows x 60 columns]

# %%
df.sample(2) #generates random data set
# Out:
#      Age Age.Group Gender Locality   Marital status                         \
# 271   51     51-60   Male      RURAL                               MARRIED
# 54    51     51-60   Male      RURAL                               MARRIED
#
#     Life.Style                                                                                \
# 271                                                YES
# 54                                                 YES
#
#     Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num  \
# 271    NO     FREE        YES       YES  ...     4.2     2   3     7   3
# 54     NO     FREE        YES       YES  ...     2.0     3   7     3   1
#
#                  SK        SK.React  Reaction  Mortality  Follow.Up
# 271               1  COUGH.BLEEDING         1          0       29.0
# 54   COUGH.BLEEDING               1         0         29        NaN
#
# [2 rows x 60 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age Age.Group  Gender Locality   Marital status                         \
# 0     45     41-50  Female      RURAL                               MARRIED
# 1     51     51-60  Female      URBAN                               MARRIED
# 2     55     51-60  Female      RURAL                               MARRIED
# 3     55     51-60  Female      RURAL                               MARRIED
# 4     56     51-60  Female      RURAL                               MARRIED
# ..   ...       ...     ...        ...                                   ...
# 363   55     51-60    Male      URBAN                               MARRIED
# 364   55     51-60    Male      RURAL                               MARRIED
# 365   58     51-60    Male      URBAN                               MARRIED
# 366   58     51-60    Male      URBAN                               MARRIED
# 367   50     41-50    Male      RURAL                               MARRIED
#
# ...

# %%
df.describe()
# Out:
#               Age   F.History    Diabetes          BP  Thrombolysis  \
# count  368.000000  368.000000  368.000000  368.000000    368.000000
# mean    54.293478    0.195652    0.461957  119.791304      4.247283
# std      8.718158    0.397242    0.499229   28.178917     40.096834
# min     24.000000    0.000000    0.000000    0.000000      0.000000
# 25%     50.750000    0.000000    0.000000  100.700000      0.000000
# 50%     55.000000    0.000000    0.000000  120.800000      0.000000
# 75%     60.250000    0.000000    1.000000  140.700000      0.000000
# max     77.000000    1.000000    1.000000  190.110000    563.000000
#
#               BGR      B.Urea        S.Cr    S.Sodium  S.Potassium  ...  \
# count  368.000000  368.000000  368.000000  368.000000   368.000000  ...
# mean   216.326087   51.148370    3.532663  136.241304     5.551087  ...
# std    139.345403   62.827701   15.846516   16.064980    11.425503  ...
# ...

# %%
all=df.describe(include="all") # describe all dataset

# %%
all
# Out:
#                Age Age.Group Gender Locality    \
# count   368.000000       368    368        368
# unique         NaN         5      2          2
# top            NaN     51-60   Male      URBAN
# freq           NaN       184    285        234
# mean     54.293478       NaN    NaN        NaN
# std       8.718158       NaN    NaN        NaN
# min      24.000000       NaN    NaN        NaN
# 25%      50.750000       NaN    NaN        NaN
# 50%      55.000000       NaN    NaN        NaN
# 75%      60.250000       NaN    NaN        NaN
# max      77.000000       NaN    NaN        NaN
#
#        Marital status                         \
# count                                    368
# unique                                     2
# top                                  MARRIED
# freq                                     365
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# ...

# %%
all.loc[["top","mean","75%"]]
# Out:
#             Age Age.Group Gender Locality    \
# top         NaN     51-60   Male      URBAN
# mean  54.293478       NaN    NaN        NaN
# 75%   60.250000       NaN    NaN        NaN
#
#      Marital status                         \
# top                                MARRIED
# mean                                   NaN
# 75%                                    NaN
#
#      Life.Style                                                                                \
# top                                                 YES
# mean                                                NaN
# 75%                                                 NaN
#
#      Sleep Category Depression Hyperlipi  ...   oldpeak     slope        ca  \
# top     NO     FREE        YES       YES  ...       NaN       NaN       NaN
# mean   NaN      NaN        NaN       NaN  ...  1.540761  1.826087  1.084239
# 75%    NaN      NaN        NaN       NaN  ...  2.200000  2.000000  2.000000
#
# ...

# %%
all.iloc[[1,2,3]] # data according to the index of that data
# Out:
#         Age Age.Group Gender Locality   Marital status                         \
# unique  NaN         5      2          2                                     2
# top     NaN     51-60   Male      URBAN                               MARRIED
# freq    NaN       184    285        234                                   365
#
#        Life.Style                                                                                \
# unique                                                  2
# top                                                   YES
# freq                                                  217
#
#        Sleep Category Depression Hyperlipi  ... oldpeak slope  ca  thal num  \
# unique     2        2          2         2  ...     NaN   NaN NaN   NaN NaN
# top       NO     FREE        YES       YES  ...     NaN   NaN NaN   NaN NaN
# freq     224      331        351       341  ...     NaN   NaN NaN   NaN NaN
#
#          SK        SK.React  Reaction  Mortality  Follow.Up
# ...

# %%
# Set pandas display option to show all rows
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
print(df[["Age", "Gender", "Category"]])
# Out:
#      Age  Gender Category
# 0     45  Female     FREE
# 1     51  Female     FREE
# 2     55  Female     FREE
# 3     55  Female     FREE
# 4     56  Female     FREE
# 5     56  Female     FREE
# 6     57  Female     PAID
# 7     57  Female     FREE
# 8     58  Female     FREE
# 9     58  Female     FREE
# 10    59  Female     FREE
# 11    60  Female     FREE
# 12    60  Female     FREE
# 13    61  Female     PAID
# 14    61  Female     FREE
# 15    62  Female     FREE
# 16    62  Female     FREE
# 17    62  Female     FREE
# 18    62  Female     FREE
# 19    62  Female     FREE
# 20    63  Female     PAID
# 21    63  Female     FREE
# 22    63  Female     FREE
# 23    65  Female     FREE
# 24    66  Female     PAID
# 25    24    Male     FREE
# 26    25    Male     FREE
# 27    35    Male     FREE
# 28    38    Male     FREE
# 29    40    Male     FREE
# 30    40    Male     PAID
# 31    44    Male     FREE
# 32    45    Male     FREE
# 33    45    Male     FREE
# ...

# %%
# Age distribution
df['Age'].plot(kind='hist', bins=20, color='lightblue', edgecolor='black', title='Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df["Age"].mean()
# Out:
# np.float64(54.29347826086956)

# %%
df["Age"].mode("age")
# Out:
# 0    50
# 1    55
# Name: Age, dtype: int64

# %%
df["Age"].median()
# Out:
# np.float64(55.0)

# %%
df = df.rename(columns={"Depression": "hypertension"})

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      285
# Female     83
# Name: count, dtype: int64

# %%
df["Gender"].value_counts().plot(kind="pie", title= "Gender",color="purple")
# Out:
# <Axes: title={'center': 'Gender'}, ylabel='count'>

# %%
df["Marital status "].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marital status '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ...

# %%
df["BP"].value_counts().plot(kind="bar", title= "BP",color="purple")
# Out:
# <Axes: title={'center': 'BP'}, xlabel='BP'>

# %%
df['Age.Group'].value_counts().plot(kind="line",title= "Age.Group",color= "red")
# Out:
# <Axes: title={'center': 'Age.Group'}, xlabel='Age.Group'>

# %%
df.isnull().sum() # show where the values are null
# Out:
# Age                                                                                         0
# Age.Group                                                                                   0
# Gender                                                                                      0
# Locality                                                                                    0
# Marital status                                                                              0
# Life.Style                                                                                  0
# Sleep                                                                                       0
# Category                                                                                    0
# hypertension                                                                                0
# Hyperlipi                                                                                   0
# ...

# %%
df[df["Follow.Up"].isnull()]
# Out:
#     Age Age.Group Gender Locality   Marital status                         \
# 45   55     51-60   Male      RURAL                               MARRIED
# 51   50     41-50   Male      RURAL                               MARRIED
# 54   51     51-60   Male      RURAL                               MARRIED
# 64   54     51-60   Male      URBAN                               MARRIED
# 68   55     51-60   Male      RURAL                               MARRIED
#
#    Life.Style                                                                                \
# 45                                                YES
# 51                                                YES
# 54                                                YES
# 64                                                YES
# 68                                                YES
#
#    Sleep Category hypertension Hyperlipi  ... oldpeak slope  ca  thal num  \
# 45   YES     FREE          YES       YES  ...     3.0     0   7     1   1
# ...

# %%
df["Care"]=df["Follow.Up"].fillna(df["Follow.Up"].mean())

# %%
df[df["Follow.Up"].isnull()]
# Out:
#     Age Age.Group Gender Locality   Marital status                         \
# 45   55     51-60   Male      RURAL                               MARRIED
# 51   50     41-50   Male      RURAL                               MARRIED
# 54   51     51-60   Male      RURAL                               MARRIED
# 64   54     51-60   Male      URBAN                               MARRIED
# 68   55     51-60   Male      RURAL                               MARRIED
#
#    Life.Style                                                                                \
# 45                                                YES
# 51                                                YES
# 54                                                YES
# 64                                                YES
# 68                                                YES
#
#    Sleep Category hypertension Hyperlipi  ... slope ca  thal  num  \
# 45   YES     FREE          YES       YES  ...     0  7     1    1
# ...

# %%
df.groupby("Gender").describe()
# Out:
#           Age                                                    F.History  \
#         count       mean       std   min   25%   50%   75%   max     count
# Gender
# Female   83.0  60.734940  5.314693  24.0  60.0  62.0  63.0  66.0      83.0
# Male    285.0  52.417544  8.625893  24.0  50.0  54.0  56.0  77.0     285.0
#
#                   ... Mortality       Follow.Up                             \
#             mean  ...       75%   max     count       mean        std  min
# Gender            ...
# Female  0.000000  ...       1.0   1.0      83.0  29.253012  17.637158  1.0
# Male    0.252632  ...       0.0  32.0     280.0  28.596429  15.311742  2.0
#
#
#          25%   50%   75%   max
# Gender
# Female  15.0  32.0  34.0  60.0
# Male    15.0  32.0  36.0  60.0
#
# [2 rows x 320 columns]

# %%
df.to_csv("data2.csv")
